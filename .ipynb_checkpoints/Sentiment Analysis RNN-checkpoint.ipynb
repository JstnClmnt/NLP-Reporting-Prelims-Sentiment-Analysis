# %%
import pandas as pd
import numpy as np

import tensorflow as tf
import keras
from keras.preprocessing.sequence import pad_sequences
from gensim.models import Word2Vec
import multiprocessing
import os

df=pd.read_csv("imdb_master.csv",encoding="utf-8")

df=df[df["label"]!="unsup"]

df=df.replace("neg", 0)
df=df.replace("pos", 1)
df.head()
# Out:
# Using TensorFlow backend.
# C:\Program Files\Python36\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
#    Unnamed: 0  type                                             review  label  \
# 0           0  test  Once again Mr. Costner has dragged out a movie...      0
# 1           1  test  This is an example of why the majority of acti...      0
# 2           2  test  First of all I hate those moronic rappers, who...      0
# 3           3  test  Not even the Beatles could write songs everyon...      0
# 4           4  test  Brass pictures (movies is not a fitting word f...      0
#
#           file
# 0      0_2.txt
# 1  10000_4.txt
# 2  10001_1.txt
# 3  10002_3.txt
# 4  10003_3.txt

# %%
df['review'] = df['review'].str.replace("[^a-zA-Z#]", " ")

# %%
traindf=df[df["type"]=="train"].sample(frac=0.5,random_state=0)
testdf=df[df["type"]=="test"].sample(frac=0.2,random_state=0)
traindf=traindf[["review","label"]]
testdf=testdf[["review","label"]]
print(len(traindf))
print(len(testdf))
# Out:
# 12500
# 5000

# %%
import nltk
from nltk.tokenize import word_tokenize

X_train=[word_tokenize(i) for i in traindf["review"].values]
y_train=traindf["label"].values
X_test=[word_tokenize(i) for i in testdf["review"].values]
y_test=testdf["label"].values

print(X_train[0])
# Out:
# ['Zero', 'Day', 'leads', 'you', 'to', 'think', 'even', 're', 'think', 'why', 'two', 'boys', 'young', 'men', 'would', 'do', 'what', 'they', 'did', 'commit', 'mutual', 'suicide', 'via', 'slaughtering', 'their', 'classmates', 'It', 'captures', 'what', 'must', 'be', 'beyond', 'a', 'bizarre', 'mode', 'of', 'being', 'for', 'two', 'humans', 'who', 'have', 'decided', 'to', 'withdraw', 'from', 'common', 'civility', 'in', 'order', 'to', 'define', 'their', 'own', 'mutual', 'world', 'via', 'coupled', 'destruction', 'It', 'is', 'not', 'a', 'perfect', 'movie', 'but', 'given', 'what', 'money', 'time', 'the', 'filmmaker', 'and', 'actors', 'had', 'it', 'is', 'a', 'remarkable', 'product', 'In', 'terms', 'of', 'explaining', 'the', 'motives', 'and', 'actions', 'of', 'the', 'two', 'young', 'suicide', 'murderers', 'it', 'is', 'better', 'than', 'Elephant', 'in', 'terms', 'of', 'being', 'a', 'film', 'that', 'gets', 'under', 'our', 'rationalistic', 'skin', 'it', 'is', 'a', 'far', 'far', 'better', 'film', 'than', 'almost', 'anything', 'you', 'are', 'likely', 'to', 'see', 'Flawed', 'but', 'honest', 'with', 'a', 'terrible', 'honesty']

# %%
words = set([])
for s in X_train:
    for w in s:
        words.add(w.lower())
word2index = {w: i + 2 for i, w in enumerate(list(words))}
word2index['-PAD-'] = 0  # The special value used for padding
word2index['-OOV-'] = 1  # The special value used for OOVs

# %%
#Declare Model Parameters
cbow = 0
skipgram = 1
EMB_DIM = 150 #more dimensions, more computationally expensive to train
min_word_count = 1
workers = multiprocessing.cpu_count() #based on computer cpu count
context_size = 7
downsampling = 1e-3
learning_rate = 0.025 #initial learning rate
min_learning_rate = 0.025 #fixated learning rate
num_epoch = 10

# %%
w2v = Word2Vec(
    sg = skipgram,
    hs = 1, #hierarchical softmax
    size = EMB_DIM,
    min_count = min_word_count, 
    workers = workers,
    window = context_size, 
    sample = downsampling, 
    alpha = learning_rate, 
    min_alpha = min_learning_rate
)

# %%
w2v.build_vocab(X_train)
w2v.train(X_train,epochs=num_epoch,total_examples=w2v.corpus_count)
words = list(w2v.wv.vocab)
print('Vocabulary size: %d' % len(words))
#save model in ASCII (word2vec) format
filename = 'embedding_word2vec.txt'
w2v.wv.save_word2vec_format(filename, binary=False)
# Out:
# Vocabulary size: 69503

# %%
embeddings_index={}
f=open(os.path.join('','embedding_word2vec.txt '),encoding="utf-8")
for line in f:
    values=line.split()
    word=values[0]
    coefs=np.asarray(values[1:])
    embeddings_index[word]=coefs
f.close()

# %%
train_sentences_X, test_sentences_X = [], []

num_words=len(word2index)+1
embedding_matrix=np.zeros((num_words,EMB_DIM))
print(word2index)
for word,i in word2index.items():
    if i>num_words:
        continue
    embedding_vector=embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i]=embedding_vector

for s in X_train:
    s_int = []
    for w in s:
        try:
            s_int.append(word2index[w.lower()])
        except KeyError:
            s_int.append(word2index['-OOV-'])
 
    train_sentences_X.append(s_int)
    
for s in X_test:
    s_int = []
    for w in s:
        try:
            s_int.append(word2index[w.lower()])
        except KeyError:
            s_int.append(word2index['-OOV-'])
 
    test_sentences_X.append(s_int)


MAX_LENGTH = len(max(train_sentences_X, key=len))
print(MAX_LENGTH)  # 271

from keras.preprocessing.sequence import pad_sequences
 
train_sentences_X = pad_sequences(train_sentences_X, maxlen=MAX_LENGTH, padding='post')
test_sentences_X = pad_sequences(test_sentences_X, maxlen=MAX_LENGTH, padding='post')

print(train_sentences_X[0])
# Out:
# {'displaying': 2, 'simon': 3, 'mutate': 4, 'frilly': 5, 'unrest': 6, 'fistful': 7, 'nestled': 8, 'dapper': 9, 'blondel': 10, 'lengths': 11, 'chats': 12, 'devotions': 13, 'yearling': 14, 'intending': 15, 'load': 16, 'hopefully': 17, 'tattooed': 18, 'horticulturalist': 19, 'achiever': 20, 'redeem': 21, 'ft': 22, 'paesan': 23, 'vanload': 24, 'stag': 25, 'nihalani': 26, 'offering': 27, 'outlook': 28, 'aguila': 29, 'illuminators': 30, 'shinbei': 31, 'byrnes': 32, 'homoerotica': 33, 'rhode': 34, 'nudes': 35, 'rebut': 36, 'wicked': 37, 'pugilist': 38, 'llydia': 39, 'perfectness': 40, 'pixely': 41, 'illbient': 42, 'eating': 43, 'quilt': 44, 'udy': 45, 'overriding': 46, 'everard': 47, 'mnm': 48, 'possessor': 49, 'midler': 50, 'responsibilty': 51, 'pony': 52, 'election': 53, 'scintillating': 54, 'ripthis': 55, 'sluts': 56, 'pajamas': 57, 'jonker': 58, 'overhaul': 59, 'outlooking': 60, 'furdion': 61, 'jelly': 62, 'dernier': 63, 'comprising': 64, 'peebles': 65, 'topher': 66, 'armitage': 67, 'poses': 68, 'junked': 69, 'mckay': 70, 'pinter': 71, 'harpies': 72, 'vessela': 73, 'components': 74, 'hologram': 75, 'daddy': 76, 'ogre': 77, 'also': 78, 'determination': 79, 'previous': 80, 'mace': 81, 'bette': 82, 'tolokonnikov': 83, 'doors': 84, 'spawn': 85, 'alienation': 86, 'alloted': 87, 'helplessly': 88, 'sage': 89, 'loss': 90, 'vanesa': 91, 'overlapped': 92, 'bois': 93, 'turquoise': 94, 'terribleness': 95, 'unselfishness': 96, 'especially': 97, 'accelerated': 98, 'fitz': 99, 'euphemisms': 100, 'notrecommend': 101, 'cope': 102, 'smoother': 103, 'irvine': 104, 'dime': 105, 'bill': 106, 'bannacheck': 107, 'courttv': 108, 'booth': 109, 'advanceother': 110, 'vacations': 111, 'franchise': 112, 'leprosy': 113, 'blasco': 114, 'affects': 115, 'feints': 116, 'recklessly': 117, 'chalice': 118, 'atheism': 119, 'elections': 120, 'chemestry': 121, 'publicity': 122, 'built': 123, 'chippendale': 124, 'giss': 125, 'munn': 126, 'nyfiken': 127, 'bobcat': 128, 'mature': 129, 'walerian': 130, 'transatlantic': 131, 'fasted': 132, 'flogged': 133, 'raindrops': 134, 'bernier': 135, 'dialoque': 136, 'predispose': 137, 'dweebs': 138, 'eppes': 139, 'simulation': 140, 'blight': 141, 'kake': 142, 'marish': 143, 'ribcage': 144, 'clinching': 145, 'caught': 146, 'waits': 147, 'guffaw': 148, 'rhind': 149, 'kelsey': 150, 'reanimated': 151, 'button': 152, 'sillyflaws': 153, 'sostrong': 154, 'enormity': 155, 'cambodia': 156, 'asked': 157, 'bemoan': 158, 'pascow': 159, 'vegetarians': 160, 'armpit': 161, 'wifey': 162, 'bronston': 163, 'rocketing': 164, 'vaccarro': 165, 'kinsey': 166, 'enticing': 167, 'unwittingly': 168, 'gameplay': 169, 'snoop': 170, 'pantry': 171, 'html': 172, 'outted': 173, 'cong': 174, 'paperboy': 175, 'jubilation': 176, 'whopper': 177, 'chauvinism': 178, 'terminology': 179, 'banana': 180, 'dale': 181, 'interludes': 182, 'yonekura': 183, 'bodied': 184, 'cool': 185, 'gables': 186, 'sexualreferences': 187, 'musketeer': 188, 'brennan': 189, 'bombed': 190, 'botcher': 191, 'shout': 192, 'shashi': 193, 'maximising': 194, 'tropical': 195, 'abeyance': 196, 'adjust': 197, 'mishmash': 198, 'lizzy': 199, 'lebrock': 200, 'tight': 201, 'blocks': 202, 'barfed': 203, 'practicing': 204, 'patiently': 205, 'trolling': 206, 'genocide': 207, 'majorca': 208, 'sanju': 209, 'jordanian': 210, 'denise': 211, 'surrealism': 212, 'rebuild': 213, 'informative': 214, 'skerritt': 215, 'retires': 216, 'awayin': 217, 'bothers': 218, 'inexpert': 219, 'beating': 220, 'assumptions': 221, 'electrifyingly': 222, 'barbour': 223, 'ethereally': 224, 'ackroyd': 225, 'hinder': 226, 'presidents': 227, 'produces': 228, 'wowzors': 229, 'vitagraph': 230, 'roles': 231, 'margot': 232, 'reconstruct': 233, 'guys': 234, 'emptiest': 235, 'lilia': 236, 'speakman': 237, 'kruger': 238, 'cannibalizing': 239, 'utensils': 240, 'rant': 241, 'cosmos': 242, 'researchers': 243, 'demographic': 244, 'unborn': 245, 'coulier': 246, 'youv': 247, 'gamestop': 248, 'tended': 249, 'champagne': 250, 'mcgee': 251, 'audery': 252, 'head ...
# 1841
# [37772  5147  1323 ...     0     0     0]

# %%
from keras import Sequential
from keras.initializers import Constant
from keras.layers import Embedding, LSTM, Dense, Dropout,CuDNNLSTM,Bidirectional,TimeDistributed,Activation,Flatten
from keras.utils import plot_model
model=Sequential() 
embedding_layer=Embedding(num_words,EMB_DIM,embeddings_initializer=Constant(embedding_matrix),input_length=MAX_LENGTH,trainable=True)
model.add(embedding_layer)
model.add(Bidirectional(CuDNNLSTM(64)))
model.add(Dropout(0.5))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1841, 150)         8459250
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               110592
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,569,971
# Trainable params: 8,569,971
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history=model.fit(train_sentences_X, y_train, validation_split=0.2, batch_size=64, epochs=5)
# Out:
# Train on 10000 samples, validate on 2500 samples
# Epoch 1/5
# 10000/10000 [==============================] - 176s 18ms/step - loss: 0.6074 - acc: 0.6740 - val_loss: 0.4641 - val_acc: 0.8048
# Epoch 2/5
# 10000/10000 [==============================] - 109s 11ms/step - loss: 0.6081 - acc: 0.6795 - val_loss: 0.6686 - val_acc: 0.6464
# Epoch 3/5
# 10000/10000 [==============================] - 121s 12ms/step - loss: 0.4598 - acc: 0.7929 - val_loss: 0.3800 - val_acc: 0.8432
# Epoch 4/5
# 10000/10000 [==============================] - 111s 11ms/step - loss: 0.2883 - acc: 0.8950 - val_loss: 0.3577 - val_acc: 0.8580
# Epoch 5/5
# 10000/10000 [==============================] - 109s 11ms/step - loss: 0.1610 - acc: 0.9483 - val_loss: 0.3863 - val_acc: 0.8564

# %%
scores = model.evaluate(test_sentences_X, y_test, verbose=0)
print('Test accuracy:', scores[1])
model.save("model.h5")
plot_model(model, to_file='model.png')
# Out:
# Test accuracy: 0.8164

# %%
import matplotlib.pyplot as plt
# Plot training & validation accuracy values
plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.figure( )
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
sample="This brings so much frustration. I do not like this show".replace("[^a-zA-Z#]", " ")
sample_X=sample.split()
sample_X_pad=[]
for w in sample_X:
    try:
        sample_X_pad.append(word2index[w.lower()])
    except KeyError:
        sample_X_pad.append(word2index['-OOV-'])
sample_X_pad=[sample_X_pad] 
sample_X_pad=pad_sequences(sample_X_pad, maxlen=MAX_LENGTH, padding='post')
sample_X_pad=sample_X_pad
print(sample_X_pad)

print(model.predict_classes(sample_X_pad))
# Out:
# [[39925 45174 53052 ...     0     0     0]]
# [[0]]

# %%
print(X_test[0])
# Out:
# ['Don', 't', 'hate', 'Heather', 'Graham', 'because', 'she', 's', 'beautiful', 'hate', 'her', 'because', 'she', 's', 'fun', 'to', 'watch', 'in', 'this', 'movie', 'Like', 'the', 'hip', 'clothing', 'and', 'funky', 'surroundings', 'the', 'actors', 'in', 'this', 'flick', 'work', 'well', 'together', 'Casey', 'Affleck', 'is', 'hysterical', 'and', 'Heather', 'Graham', 'literally', 'lights', 'up', 'the', 'screen', 'The', 'minor', 'characters', 'Goran', 'Visnjic', 'sigh', 'and', 'Patricia', 'Velazquez', 'are', 'as', 'TALENTED', 'as', 'they', 'are', 'gorgeous', 'Congratulations', 'Miramax', 'Director', 'Lisa', 'Krueger']

# %%
sample=X_test[0.replace("[^a-zA-Z#]", " ")
sample_X=sample.split()
sample_X_pad=[]
for w in sample_X:
    try:
        sample_X_pad.append(word2index[w.lower()])
    except KeyError:
        sample_X_pad.append(word2index['-OOV-'])
sample_X_pad=[sample_X_pad] 
sample_X_pad=pad_sequences(sample_X_pad, maxlen=MAX_LENGTH, padding='post')
sample_X_pad=sample_X_pad
print(sample_X_pad)

print(model.predict_classes(sample_X_pad))
